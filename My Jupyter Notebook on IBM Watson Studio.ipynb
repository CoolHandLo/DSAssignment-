# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lo Evans**
# Data Scienctist

# %% [markdown]
# *Data Science is a natural pursuit for me. I'm interested in it for many reasons: I enjoy discovering new thing, love math and science, and would like a nice paycheck.*

# %% [markdown]
# ### The code below adds 1 to 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - item 1
# - item 2
# - item 3
# ---
# 1. item 1b
# 2. item 2b
# 3. item 3b
